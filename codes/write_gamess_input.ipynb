# %%
from openbabel import pybel
from pathlib import Path

# %%
def read_file(format, filename):
    pybel.ob.obErrorLog.SetOutputLevel(0)
    mols = list(pybel.readfile(format, filename))
    return (mols)

# %%
file = Path("Class_Benzene and substituted derivatives.smi")
format_in = file.suffix[1:]

# %%
mols = read_file(format_in, file.name)
multi = [x.OBMol.GetTotalSpinMultiplicity() for x in mols]
print(multi)
for line in mols:
    line.make3D()
    print(line.OBMol.GetTotalSpinMultiplicity())
# Out:
# [2, 2]
# 1
# 1
